# %%
from datetime import datetime
import backtrader as bt
import matplotlib.pyplot as plt

# %%
class Strat(bt.Strategy):
    def __init__(self):
        self.UPRO = self.getdatabyname('UPRO')
        self.TMF = self.getdatabyname('TMF')
        self.counter = 0
        
    def next(self):
        if  self.counter % 20 == 0:
            self.order_target_percent(self.UPRO, target=.5)
            self.order_target_percent(self.TMF, target=.5)
        self.counter += 1


start = datetime(1999,1,1)
end = datetime(2019,1,1)

cerebro = bt.Cerebro()

upro = bt.feeds.YahooFinanceData(dataname='UPRO',
                                 fromdate=start,
                                 todate=end)

tmf = bt.feeds.YahooFinanceData(dataname='TMF',
                                 fromdate=start,
                                 todate=end)

cerebro.adddata(upro)
cerebro.adddata(tmf)

cerebro.addstrategy(Strat)
cerebro.addanalyzer(bt.analyzers.PyFolio, _name='pyfolio') 

results = cerebro.run()
cerebro.plot()
# Out:
# <img src="data:image/png;base64,..." width="432">
# [[<Figure size 432x288 with 6 Axes>]]

# %%
import pyfolio as pf
# Out:
# /usr/local/lib/python3.7/site-packages/pyfolio/pos.py:27: UserWarning: Module "zipline.assets" not found; mutltipliers will not be applied to position notionals.
#   'Module "zipline.assets" not found; mutltipliers will not be applied' +

# %%
strat = results[0]
pyfoliozer = strat.analyzers.getbyname('pyfolio')
returns, positions, transactions, gross_lev = pyfoliozer.get_pf_items()
pf.create_simple_tear_sheet(returns, positions=positions, transactions=transactions,)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2009-04-16</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2018-12-31</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>116</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>23.3%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>663.2%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>22.1%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>1.06</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.96</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.97</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-24.3%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.20</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>1.52</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>-0.30</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>1.93</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.00</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-2.7%</td>
#     </tr>
#     <tr>
#       <th>Gross leverage</th>
#       <td>0.93</td>
#     </tr>
#     <tr>
#       <th>Daily turnover</th>
#       <td>0.5%</td>
#     </tr>
#   </tbody>
# </table>
# <img src="data:image/png;base64,..." width="1008">
